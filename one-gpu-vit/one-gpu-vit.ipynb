# %%
import torch
from transformers import ViTFeatureExtractor, ViTForImageClassification, TrainingArguments, Trainer
from datasets import load_dataset
from evaluate import load
import numpy as np
from transformers import DefaultDataCollator
from torchvision import transforms

from accelerate import Accelerator

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %%
# establish which LLM to train on
model_name = 'google/vit-base-patch16-224-in21k'
run_name = model_name + '_run0'

# %%
# build dataset
food_dataset = load_dataset("food101")
# Out:
# Found cached dataset food101 (/home/ref2156/.cache/huggingface/datasets/food101/default/0.0.0/7cebe41a80fb2da3f08fcbef769c8874073a86346f7fb96dc0847d4dfc318295)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
labels = food_dataset["train"].features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = str(i)
    id2label[str(i)] = label

# %%
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name)
model = ViTForImageClassification.from_pretrained(model_name,
                                                  num_labels=len(labels),
                                                  id2label=id2label,
                                                  label2id=label2id).to(device)
# Out:
# /opt/conda/lib/python3.7/site-packages/transformers/models/vit/feature_extraction_vit.py:31: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   FutureWarning,
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing ViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# define fine-tuning hyper parameters
epochs = 8
per_dev_batch_size = 16
output_dir = './vit'
lr = 5e-5

# %%
data_collator = DefaultDataCollator()

# %%
# define image transformations
normalize = transforms.Normalize(mean=feature_extractor.image_mean, std=feature_extractor.image_std)
size = (feature_extractor.size["shortest_edge"]
        if "shortest_edge" in feature_extractor.size
        else (feature_extractor.size["height"], feature_extractor.size["width"])
        )
img_transforms = transforms.Compose([transforms.RandomResizedCrop(size), transforms.ToTensor(), normalize])


# define function to prepare dataset for huggingface implementation
def transform_data(examples):
    examples["pixel_values"] = [img_transforms(img.convert("RGB")) for img in examples["image"]]
    del examples["image"]
    return examples

# %%
food_dataset = food_dataset.with_transform(transform_data)

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return accuracy.compute(predictions=predictions, references=labels)

# %%
training_args = TrainingArguments(
    output_dir=output_dir + run_name,
    remove_unused_columns=False,
    evaluation_strategy="epoch",
    save_strategy="epoch",
    learning_rate=lr,
    per_device_train_batch_size=per_dev_batch_size,
    gradient_accumulation_steps=4,
    per_device_eval_batch_size=per_dev_batch_size,
    num_train_epochs=epochs,
    warmup_ratio=0.1,
    logging_steps=10,
    load_best_model_at_end=True,
    metric_for_best_model="accuracy",
)

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=food_dataset["train"],
    eval_dataset=food_dataset["validation"],
    tokenizer=feature_extractor,
    compute_metrics=compute_metrics,
)

# %%
trainer.train()
# Out:
# /opt/conda/lib/python3.7/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='9' max='2368' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   9/2368 00:29 < 2:46:05, 0.24 it/s, Epoch 0.03/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 trainer.train()                                                                              │
# │   2                                                                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/transformers/trainer.py:1666 in train                     │
# │                                                                                                  │
# │   1663 │   │   │   args=args,                                                                    │
# │   1664 │   │   │   resume_from_checkpoint=resume_from_checkpoint,                                │
# │   1665 │   │   │   trial=trial,                                                                  │
# │ ❱ 1666 │   │   │   ignore_keys_for_eval=ignore_keys_for_eval,                                    │
# │   1667 │   │   )                                                                                 │
# │   1668 │                                                                                         │
# │   1669 │   def _inner_training_loop(                                                             │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/transformers/trainer.py:1899 in _inner_training_loop      │
# │                                                                                                  │
# │   1896 │   │   │   │   rng_to_sync = True                                                        │
# │   1897 │   │   │                                                                                 │
# │   1898 │   │   │   step = -1                                                                     │
# │ ❱ 1899 │   │   │   for step, inputs in enumerate(epoch_iterator):                                │
# │   1900 │   │   │   │   total_batched_samples += 1                                                │
# │   1901 │   │   │   │   if rng_to_sync:                                                           │
# │   1902 │   │   │   │   │   self._load_rng_state(resume_from_checkpoint)                          │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py:530 in __next__            │
# │                                                                                                  │
# │    527 │   │   with torch.autograd.profiler.record_function(self._profile_name):                 │
# │    528 │   │   │   if self._sampler_iter is None:                                                │
# │    529 │   │   │   │   self._reset()                                                             │
# │ ❱  530 │   │   │   data = self._next_data()                                                      │
# │    531 │   │   │   self._num_yielded += 1                                                        │
# │    532 │   │   │   if self._dataset_kind == _DatasetKind.Iterable and \                          │
# │    533 │   │   │   │   │   self._IterableDataset_len_called is not None and \                    │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/torch/utils/data/dataloader.py:570 in _next_data          │
# │                                                                                                  │
# │    567 │                                                                                         │
# │    568 │   def _next_data(self):                                                                 │
# │    569 │   │   index = self._next_index()  # may raise StopIteration                             │
# │ ❱  570 │   │   data = self._dataset_fetcher.fetch(index)  # may raise StopIteration              │
# │    571 │   │   if self._pin_memory:                                                              │
# │    572 │   │   │   data = _utils.pin_memory.pin_memory(data)                                     │
# │    573 │   │   return data                                                                       │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py:49 in fetch              │
# │                                                                                                  │
# │   46 │                                                                                           │
# │   47 │   def fetch(self, possibly_batched_index):                                                │
# │   48 │   │   if self.auto_collation:                                                             │
# │ ❱ 49 │   │   │   data = [self.dataset[idx] for idx in possibly_batched_index]                    │
# │   50 │   │   else:                                                                               │
# │   51 │   │   │   data = self.dataset[possibly_batched_index]                                     │
# │   52 │   │   return self.collate_fn(data)                                                        │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py:49 in <listcomp>         │
# │                                                                                                  │
# │   46 │                                                                                           │
# │   47 │   def fetch(self, possibly_batched_index):                                                │
# │   48 │   │   if self.auto_collation:                                                             │
# │ ❱ 49 │   │   │   data = [self.dataset[idx] for idx in possibly_batched_index]                    │
# │   50 │   │   else:                                                                               │
# │   51 │   │   │   data = self.dataset[possibly_batched_index]                                     │
# │   52 │   │   return self.collate_fn(data)                                                        │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/arrow_dataset.py:2778 in __getitem__             │
# │                                                                                                  │
# │   2775 │                                                                                         │
# │   2776 │   def __getitem__(self, key):  # noqa: F811                                             │
# │   2777 │   │   """Can be used to index columns (by string names) or rows (by integer index or i  │
# │ ❱ 2778 │   │   return self._getitem(key)                                                         │
# │   2779 │                                                                                         │
# │   2780 │   def __getitems__(self, keys: List) -> List:                                           │
# │   2781 │   │   """Can be used to get a batch using a list of integers indices."""                │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/arrow_dataset.py:2764 in _getitem                │
# │                                                                                                  │
# │   2761 │   │   formatter = get_formatter(format_type, features=self._info.features, **format_kw  │
# │   2762 │   │   pa_subtable = query_table(self._data, key, indices=self._indices if self._indice  │
# │   2763 │   │   formatted_output = format_table(                                                  │
# │ ❱ 2764 │   │   │   pa_subtable, key, formatter=formatter, format_columns=format_columns, output  │
# │   2765 │   │   )                                                                                 │
# │   2766 │   │   return formatted_output                                                           │
# │   2767                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/formatting/formatting.py:624 in format_table     │
# │                                                                                                  │
# │   621 │   query_type = key_to_query_type(key)                                                    │
# │   622 │   python_formatter = PythonFormatter(features=None)                                      │
# │   623 │   if format_columns is None:                                                             │
# │ ❱ 624 │   │   return formatter(pa_table, query_type=query_type)                                  │
# │   625 │   elif query_type == "column":                                                           │
# │   626 │   │   if key in format_columns:                                                          │
# │   627 │   │   │   return formatter(pa_table, query_type)                                         │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/formatting/formatting.py:396 in __call__         │
# │                                                                                                  │
# │   393 │                                                                                          │
# │   394 │   def __call__(self, pa_table: pa.Table, query_type: str) -> Union[RowFormat, ColumnFo   │
# │   395 │   │   if query_type == "row":                                                            │
# │ ❱ 396 │   │   │   return self.format_row(pa_table)                                               │
# │   397 │   │   elif query_type == "column":                                                       │
# │   398 │   │   │   return self.format_column(pa_table)                                            │
# │   399 │   │   elif query_type == "batch":                                                        │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/formatting/formatting.py:480 in format_row       │
# │                                                                                                  │
# │   477 │   │   self.transform = transform                                                         │
# │   478 │                                                                                          │
# │   479 │   def format_row(self, pa_table: pa.Table) -> dict:                                      │
# │ ❱ 480 │   │   formatted_batch = self.format_batch(pa_table)                                      │
# │   481 │   │   try:                                                                               │
# │   482 │   │   │   return _unnest(formatted_batch)                                                │
# │   483 │   │   except Exception as exc:                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/formatting/formatting.py:509 in format_batch     │
# │                                                                                                  │
# │   506 │                                                                                          │
# │   507 │   def format_batch(self, pa_table: pa.Table) -> dict:                                    │
# │   508 │   │   batch = self.python_arrow_extractor().extract_batch(pa_table)                      │
# │ ❱ 509 │   │   batch = self.python_features_decoder.decode_batch(batch)                           │
# │   510 │   │   return self.transform(batch)                                                       │
# │   511                                                                                            │
# │   512                                                                                            │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/formatting/formatting.py:221 in decode_batch     │
# │                                                                                                  │
# │   218 │   │   return self.features.decode_column(column, column_name) if self.features else co   │
# │   219 │                                                                                          │
# │   220 │   def decode_batch(self, batch: dict) -> dict:                                           │
# │ ❱ 221 │   │   return self.features.decode_batch(batch) if self.features else batch               │
# │   222                                                                                            │
# │   223                                                                                            │
# │   224 class PandasFeaturesDecoder:                                                               │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/features/features.py:1924 in decode_batch        │
# │                                                                                                  │
# │   1921 │   │   │   │   │   else None                                                             │
# │   1922 │   │   │   │   │   for value in column                                                   │
# │   1923 │   │   │   │   ]                                                                         │
# │ ❱ 1924 │   │   │   │   if self._column_requires_decoding[column_name]                            │
# │   1925 │   │   │   │   else column                                                               │
# │   1926 │   │   │   )                                                                             │
# │   1927 │   │   return decoded_batch                                                              │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/features/features.py:1922 in <listcomp>          │
# │                                                                                                  │
# │   1919 │   │   │   │   │   decode_nested_example(self[column_name], value, token_per_repo_id=to  │
# │   1920 │   │   │   │   │   if value is not None                                                  │
# │   1921 │   │   │   │   │   else None                                                             │
# │ ❱ 1922 │   │   │   │   │   for value in column                                                   │
# │   1923 │   │   │   │   ]                                                                         │
# │   1924 │   │   │   │   if self._column_requires_decoding[column_name]                            │
# │   1925 │   │   │   │   else column                                                               │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/features/features.py:1319 in                     │
# │ decode_nested_example                                                                            │
# │                                                                                                  │
# │   1316 │   elif isinstance(schema, (Audio, Image)):                                              │
# │   1317 │   │   # we pass the token to read and decode files from private repositories in stream  │
# │   1318 │   │   if obj is not None and schema.decode:                                             │
# │ ❱ 1319 │   │   │   return schema.decode_example(obj, token_per_repo_id=token_per_repo_id)        │
# │   1320 │   return obj                                                                            │
# │   1321                                                                                           │
# │   1322                                                                                           │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/datasets/features/image.py:178 in decode_example          │
# │                                                                                                  │
# │   175 │   │   │   │   │   image = PIL.Image.open(bytes_)                                         │
# │   176 │   │   else:                                                                              │
# │   177 │   │   │   image = PIL.Image.open(BytesIO(bytes_))                                        │
# │ ❱ 178 │   │   image.load()  # to avoid "Too many open files" errors                              │
# │   179 │   │   return image                                                                       │
# │   180 │                                                                                          │
# │   181 │   def flatten(self) -> Union["FeatureType", Dict[str, "FeatureType"]]:                   │
# │                                                                                                  │
# │ /opt/conda/lib/python3.7/site-packages/PIL/ImageFile.py:269 in load                              │
# │                                                                                                  │
# │   266 │   │   │   │   │   │   │   │   │   raise OSError(msg)                                     │
# │   267 │   │   │   │   │   │   │                                                                  │
# │   268 │   │   │   │   │   │   │   b = b + s                                                      │
# │ ❱ 269 │   │   │   │   │   │   │   n, err_code = decoder.decode(b)                                │
# │   270 │   │   │   │   │   │   │   if n < 0:                                                      │
# │   271 │   │   │   │   │   │   │   │   break                                                      │
# │   272 │   │   │   │   │   │   │   b = b[n:]                                                      │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
